# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Rotation

# %%
img = cv2.imread('test.jpg',1)
rows,cols,ch = img.shape
cx = 100
cy = 100
theta = 45
M = cv2.getRotationMatrix2D((cx,cy),theta,1)
dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.circle(dst,(cx,cy),10,(0,0,255),1)
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Affine Transformation

# %%
img = cv2.imread('dsu4.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231]])
pts2 = np.float32([[235,457],[235,270],[570,270]])
M = cv2.getAffineTransform(pts1,pts2)
dst = cv2.warpAffine(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(img),plt.title('Output')
plt.show()

# %% [markdown]
# ## Perspective Transforemation

# %%
img = cv2.imread('dsu4.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[235,457],[238,269],[569,231],[564,493]])
pts2 = np.float32([[235,457],[235,270],[570,270],[570,457]])
##M = cv2.getAffineTransform(pts1,pts2)
M = cv2.getPerspectiveTransform(pts1,pts2)
##dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('dsu5.jpg',1)
rows,cols,ch = img.shape
pts1 = np.float32([[578,336],[588,547],[755,375],[765,543]])
pts2 = np.float32([[578,336],[588,547],[755,336],[765,541]])
##M = cv2.getAffineTransform(pts1,pts2)
M = cv2.getPerspectiveTransform(pts1,pts2)
##dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
img = cv2.imread('exam.png',1)
rows,cols,ch = img.shape
pts1 = np.float32([[288,472],[1038,490],[1014,1594],[222,1552]])
pts2 = np.float32([[288,472],[1038,472],[1038,1594],[288,1594]])
##M = cv2.getAffineTransform(pts1,pts2)
M = cv2.getPerspectiveTransform(pts1,pts2)
##dst = cv2.warpAffine(img,M,(cols,rows))
dst = cv2.warpPerspective(img,M,(cols,rows))
plt.subplot(121),plt.imshow(img),plt.title('Input')
plt.subplot(122),plt.imshow(dst),plt.title('Output')
plt.show()

# %%
cv2.imshow('img',dst)
cv2.waitKey(0)
cv2.destroyAllWindows()
